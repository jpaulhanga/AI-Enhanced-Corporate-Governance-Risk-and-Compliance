# %%
# If y_type has continuous values (e.g., 0.0-1.0 risk scores), convert to binary
y_type_bin = (y_type > 0.5).astype(int)  # threshold at 0.5

from sklearn.multioutput import MultiOutputClassifier
from sklearn.linear_model import LogisticRegression

clf_type = MultiOutputClassifier(LogisticRegression(max_iter=1000))
clf_type.fit(X_num, y_type_bin)

type_pred = clf_type.predict(X_num)
np.savetxt("risk_type_pred.csv", type_pred, fmt='%d', delimiter=',')
print("✅ Risk Type predictions saved → risk_type_pred.csv")
# Out:
# ✅ Risk Type predictions saved → risk_type_pred.csv
