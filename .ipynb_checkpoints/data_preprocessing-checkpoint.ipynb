# %%
import pandas as pd 
import warnings 
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
file_path_corporate_finance  = 'Corporate_Financial_Risk_Assessment_Data.csv'

df_corporate_finance = pd.read_csv(file_path_corporate_finance)
df_corporate_finance.columns = [c.strip().lower() for c in df_corporate_finance.columns]

df_corporate_finance = df_corporate_finance.rename(columns={"company_id":"ticker"})

if "date" in df_corporate_finance.columns:
    df_corporate_finance["year"] = pd.to_datetime(df_corporate_finance["date"], errors="coerce").dt.year
    
CF=df_corporate_finance[["ticker","year"]].dropna().drop_duplicates()
display(CF)
# Out:
#      ticker  year
# 0     C5706  2024
# 1     C1577  2022
# 2     C5016  2016
# 3     C2817  2019
# 4     C2287  2015
# ...     ...   ...
# 4990  C2034  2015
# 4991  C5244  2015
# 4992  C5318  2016
# 4996  C1999  2019
# 4999  C2131  2018
#
# [3575 rows x 2 columns]

# %%
file_path_SEC_financial_summary  = 'SEC_DATA_EDGAR_3 - Sheet1.csv'

df_financial_summary = pd.read_csv(file_path_SEC_financial_summary)
df_financial_summary.columns = [c.strip().lower() for c in df_financial_summary.columns]
df_financial_summary["ticker"] = df_financial_summary["company"].replace({
    "Tesla": "TSLA",
    "Microsoft": "MSFT",
    "Apple": "AAPL"
})
df_financial_summary = df_financial_summary.rename(columns={"fiscal year":"year"})
    
#df_financial_summary.head()
FS=df_financial_summary[["ticker","year"]].dropna().drop_duplicates()
display(FS)
# Out:
#   ticker  year
# 0   TSLA  2020
# 1   TSLA  2021
# 2   TSLA  2022
# 3   MSFT  2020
# 4   MSFT  2021
# 5   MSFT  2022
# 6   AAPL  2020
# 7   AAPL  2021
# 8   AAPL  2022

# %%
file_path_public_company_ESG  = 'data.csv'

df_public_company_ESG = pd.read_csv(file_path_public_company_ESG)
df_public_company_ESG.columns = [c.strip().lower() for c in df_public_company_ESG.columns]

if "last_processing_date" in df_public_company_ESG.columns:
    df_public_company_ESG["year"] = pd.to_datetime(df_public_company_ESG["last_processing_date"], format="%d-%m-%Y", errors="coerce").dt.year

PC=df_public_company_ESG[["ticker","year"]].dropna().drop_duplicates()
display(PC)
# Out:
#     ticker  year
# 0      dis  2022
# 1       gm  2022
# 2      gww  2022
# 3      mhk  2022
# 4      lyv  2022
# ..     ...   ...
# 717     hi  2022
# 718    hhc  2022
# 719   hubs  2022
# 720   hesm  2022
# 721    hei  2022
#
# [722 rows x 2 columns]

# %%
file_path_SP_500_ESG = 'SP 500 ESG Risk Ratings.csv'

df_SP_500_ESG= pd.read_csv(file_path_SP_500_ESG )
df_SP_500_ESG.columns = [c.strip().lower() for c in df_SP_500_ESG.columns]
df_SP_500_ESG = df_SP_500_ESG.rename(columns={"symbol":"ticker"})

SP = df_SP_500_ESG[["ticker"]].dropna().drop_duplicates()
display(SP)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 file_path_SP_500_ESG = '/home/project/Documents/mgmt/SP 500 ESG Risk Ratings.csv'
# ----> 3 df_SP_500_ESG= pd.read_csv(file_path_SP_500_ESG )
#       4 df_SP_500_ESG.columns = [c.strip().lower() for c in df_SP_500_ESG.columns]
#       5 df_SP_500_ESG = df_SP_500_ESG.rename(columns={"symbol":"ticker"})
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/project/Documents/mgmt/SP 500 ESG Risk Ratings.csv'

# %%
#Unified dataset aligned on (ticker, year)

unified = (CF.merge(FS, on=["ticker", "year"], how="outer").merge(PC, on=["ticker", "year"], how="outer").merge(SP, on="ticker", how="outer"))
unified['year'] =unified['year'].astype('Int64')
display(unified)
# Out:
#      ticker  year
# 0     C5706  2024
# 1     C1577  2022
# 2     C5016  2016
# 3     C2817  2019
# 4     C2287  2015
# ...     ...   ...
# 4801    ACN  <NA>
# 4802   ABBV  <NA>
# 4803    ABT  <NA>
# 4804    AOS  <NA>
# 4805    MMM  <NA>
#
# [4806 rows x 2 columns]

# %%
unified.to_csv("unified_dataset.csv", index=False)
print("Saved as 'unified_dataset.csv'")
# Out:
# Saved as 'unified_dataset.csv'
